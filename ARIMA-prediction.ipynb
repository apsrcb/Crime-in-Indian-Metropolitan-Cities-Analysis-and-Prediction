# %% [markdown]
# # DATA PROCESSING

# %%
# for various data manipulation, analysis, and mathematical operations
import numpy as np
import pandas as pd

# %%
data_eo = pd.read_csv(r'C:\Users\USER\Desktop\data\Economic Offences.csv')
data_w = pd.read_csv(r'C:\Users\USER\Desktop\data\Crime Against Women .csv')
data_cc = pd.read_csv(r'C:\Users\USER\Desktop\data\Cyber Crime.csv')
data_v = pd.read_csv(r'C:\Users\USER\Desktop\data\Violent Crimes.csv')
data_ka = pd.read_csv(r'C:\Users\USER\Desktop\data\Kidnapping and Abduction.csv')
data_sll = pd.read_csv(r'C:\Users\USER\Desktop\data\SLL.csv')
data_ipc = pd.read_csv(r'C:\Users\USER\Desktop\data\IPC.csv')

# %%
data = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(data_eo, data_w, on=['City', 'Year'], how='inner'), data_cc, on=['City', 'Year'], how='inner'), data_v, on=['City', 'Year'], how='inner'), data_ka, on=['City', 'Year'], how='inner'), data_sll, on=['City', 'Year'], how='inner'), data_ipc, on=['City', 'Year'], how='inner')

# %%
data.to_csv('dataset_data.csv', index=False)

# %%
data=data.dropna(axis=1,how='all')

# %%
data.isnull()
# Out:
#      Year   City  eo cases  w cases  cc cases  violent cases  \
# 0   False  False     False    False     False          False
# 1   False  False     False    False     False          False
# 2   False  False     False    False     False          False
# 3   False  False     False    False     False          False
# 4   False  False     False    False     False          False
# ..    ...    ...       ...      ...       ...            ...
# 90  False  False     False    False     False          False
# 91  False  False     False    False     False          False
# 92  False  False     False    False     False          False
# 93  False  False     False    False     False          False
# 94  False  False     False    False     False          False
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0              False             False             False           False  ...
# 1              False             False             False           False  ...
# 2              False             False             False           False  ...
# 3              False             False             False           False  ...
# 4              False             False             False           False  ...
# ..               ...               ...               ...             ...  ...
# 90             False             False             False           False  ...
# 91             False             False             False           False  ...
# 92             False             False             False           False  ...
# 93             False             False             False           False  ...
# 94             False             False             False           False  ...
#
#     18 to 30 yrs- F  18 to 30 yrs- T  30 to 60 yrs- M  30 to 60 yrs- F  \
# 0             False            False            False            False
# 1             False            False            False            False
# 2             False            False            False            False
# 3             False            False            False            False
# 4             False            False            False            False
# ..              ...              ...              ...              ...
# 90            False            False            False            False
# 91            False            False            False            False
# 92            False            False            False            False
# 93            False            False            False            False
# 94            False            False            False            False
#
#     30 to 60 yrs- T  Above 60 yrs- M  Above 60 yrs- F  Above 60 yrs- T  \
# 0             False            False            False            False
# 1             False            False            False            False
# 2             False            False            False            False
# 3             False            False            False            False
# 4             False            False            False            False
# ..              ...              ...              ...              ...
# 90            False            False            False            False
# 91            False            False            False            False
# 92            False            False            False            False
# 93            False            False            False            False
# 94            False            False            False            False
#
#     sll cases  ipc cases
# 0       False      False
# 1       False      False
# 2       False      False
# 3       False      False
# 4       False      False
# ..        ...        ...
# 90      False      False
# 91      False      False
# 92      False      False
# 93      False      False
# 94      False      False
#
# [95 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 0 to 94
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              95 non-null     int64
#  1   City              95 non-null     object
#  2   eo cases          95 non-null     int64
#  3   w cases           95 non-null     int64
#  4   cc cases          95 non-null     int64
#  5   violent cases     95 non-null     int64
#  6   Below 6 Years- M  95 non-null     int64
#  7   Below 6 Years- F  95 non-null     int64
#  8   Below 6 Years- T  95 non-null     int64
#  9   6 to 12 yrs- M    95 non-null     int64
#  10  6 to 12 yrs- F    95 non-null     int64
#  11  6 to 12 yrs- T    95 non-null     int64
#  12  12  to 16 yrs- M  95 non-null     int64
#  13  12  to 16 yrs- F  95 non-null     int64
#  14  12  to 16 yrs- T  95 non-null     int64
#  15  16  to 18 yrs- M  95 non-null     int64
#  16  16  to 18 yrs- F  95 non-null     int64
#  17  16  to 18 yrs- T  95 non-null     int64
#  18  18 to 30 yrs- M   95 non-null     int64
#  19  18 to 30 yrs- F   95 non-null     int64
#  20  18 to 30 yrs- T   95 non-null     int64
#  21  30 to 60 yrs- M   95 non-null     int64
#  22  30 to 60 yrs- F   95 non-null     int64
#  23  30 to 60 yrs- T   95 non-null     int64
#  24  Above 60 yrs- M   95 non-null     int64
#  25  Above 60 yrs- F   95 non-null     int64
#  26  Above 60 yrs- T   95 non-null     int64
#  27  sll cases         95 non-null     int64
#  28  ipc cases         95 non-null     int64
# dtypes: int64(28), object(1)
# memory usage: 22.3+ KB

# %%
# Drop multiple columns
columns_to_drop = ['Below 6 Years- M', 'Below 6 Years- F', 'Below 6 Years- T',
       '6 to 12 yrs- M', '6 to 12 yrs- F', '6 to 12 yrs- T',
       '12  to 16 yrs- M', '12  to 16 yrs- F', '12  to 16 yrs- T',
       '16  to 18 yrs- M', '16  to 18 yrs- F', '16  to 18 yrs- T',
       '18 to 30 yrs- M', '18 to 30 yrs- F', '18 to 30 yrs- T',
       '30 to 60 yrs- M', '30 to 60 yrs- F', '30 to 60 yrs- T',
       'Above 60 yrs- M', 'Above 60 yrs- F', 'Above 60 yrs- T']
abc = data.drop(columns_to_drop, axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 0 to 94
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           95 non-null     int64
#  1   City           95 non-null     object
#  2   eo cases       95 non-null     int64
#  3   w cases        95 non-null     int64
#  4   cc cases       95 non-null     int64
#  5   violent cases  95 non-null     int64
#  6   sll cases      95 non-null     int64
#  7   ipc cases      95 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 6.7+ KB

# %%
data.to_csv('dataset2_data.csv', index=False)

# %%
a=data.columns
print(a)
# Out:
# Index(['Year', 'City', 'eo cases', 'w cases', 'cc cases', 'violent cases',
#        'sll cases', 'ipc cases'],
#       dtype='object')

# %% [markdown]
# # Time Series Model - ARIMA

# %% [markdown]
# #### For the present training data

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Sort the data by 'Year' column in ascending order
data.sort_values('Year', inplace=True)

# Split the data into training and testing sets
train_data = data[:-3]  # Use all but the last 3 years as training data
test_data = data[-3:]   # Use the last 3 years as testing data

# Fit the ARIMA model on the training data
model = ARIMA(train_data['eo cases'], order=(1, 1, 0))  # ARIMA(1, 1, 0) model
model_fit = model.fit()

# Forecast 'eo cases' for the next 3 years
forecast = model_fit.forecast(steps=3)

# Print the forecasted values
print(forecast)
# Out:
# 92    483.817630
# 93    460.623272
# 94    471.422225
# Name: predicted_mean, dtype: float64
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Sort the data by 'Year' column in ascending order
data.sort_values('Year', inplace=True)

# Get a list of unique cities in the dataset
cities = data['City'].unique()

# Create an empty DataFrame to store the forecasts for 2024
forecast_2024_df = pd.DataFrame(columns=['City', 'Forecast'])

# Iterate over each city and make forecasts for 2024
for city in cities:
    # Filter the data for the current city
    city_data = data[data['City'] == city]
    
    # Check if the data is available for the current city
    if city_data.shape[0] >= 4:
        # Split the data into training and testing sets
        train_data = city_data[:-1]  # Use all but the last 1 year as training data
        
        # Extract the 'eo cases' values as a 1D array
        train_cases = train_data['eo cases'].values
        
        # Fit the ARIMA model on the training data
        model = ARIMA(train_cases, order=(1, 1, 0))  # ARIMA(1, 1, 0) model
        model_fit = model.fit()
        
        # Forecast 'eo cases' for the year 2024
        forecast_2024 = model_fit.forecast(steps=1)[0]  # Get only the forecast for 2024
        
        # Append the forecast for the current city to the main DataFrame
        city_forecast_2024_df = pd.DataFrame({
            'City': city,
            'Forecast': forecast_2024
        }, index=[0])  # Create a DataFrame with a single row
        
        # Append the city forecast for 2024 to the main DataFrame
        forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
    else:
        print(f"Insufficient data for {city}. Skipping the forecast.")

# Print the forecasted values for 2024
print(forecast_2024_df)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3194936850.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
#           City     Forecast
# 0    Ahmedabad   708.425587
# 1       Mumbai  3969.192988
# 2      Kolkata  1461.289034
# 3    Kozhikode   357.474841
# 4        Surat   321.998724
# 5       Nagpur   469.429661
# 6         Pune   845.596525
# 7      Lucknow  2023.392658
# 8        Kochi   484.879548
# 9        Patna   881.960653
# 10      Jaipur  4115.744402
# 11  Coimbatore    94.992912
# 12      Indore   380.991855
# 13   Hyderabad  3323.225737
# 14   Bengaluru  1726.108620
# 15   Ghaziabad   397.767708
# 16     Chennai   739.651339
# 17      Kanpur   227.172037
# 18       Delhi  4815.967538

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Calculate evaluation metrics for the forecast
actual_values = city_data['eo cases'].values[-1:]  # Actual values for the last 1 year
predicted_values = np.array([forecast_2024])  # Forecasted value for 2024

# Calculate evaluation metrics
mae = mean_absolute_error(actual_values, predicted_values)
mse = mean_squared_error(actual_values, predicted_values)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((actual_values - predicted_values) / actual_values)) * 100
r2 = r2_score(actual_values, predicted_values)

# Print the evaluation metrics for the forecast
print(f"Evaluation metrics for {city}:")
print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
print("-------------------------------------")
# Out:
# Evaluation metrics for Ahmedabad:
# MAE: 56.57
# MSE: 3200.66
# RMSE: 56.57
# MAPE: 7.40%
# -------------------------------------
# C:\Users\USER\anaconda\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
# Initialize empty lists to store the evaluation metrics for all cities
mae_list = []
mse_list = []
rmse_list = []
mape_list = []
r2_list = []

# Iterate over each city and calculate evaluation metrics for the forecast
for city in cities:
    # Filter the data for the current city
    city_data = data[data['City'] == city]
    
    # Check if the data is available for the current city
    if city_data.shape[0] >= 4:
        # Split the data into training and testing sets
        train_data = city_data[:-1]  # Use all but the last 3 years as training data
        
        # Extract the 'eo cases' values as a 1D array
        train_cases = train_data['eo cases'].values.flatten()
        
        # Fit the ARIMA model on the training data
        model = ARIMA(train_cases, order=(1, 1, 0))  # ARIMA(1, 1, 0) model
        model_fit = model.fit()
        
        # Forecast 'eo cases' for the year 2024
        forecast_2024 = model_fit.forecast(steps=1)[0]  # Get only the forecast for 2024
        
        # Append the forecast for the current city to the main DataFrame
        city_forecast_2024_df = pd.DataFrame({
            'City': city,
            'Forecast': forecast_2024
        }, index=[0])  # Create a DataFrame with a single row
        
        # Append the city forecast for 2024 to the main DataFrame
        forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
        
        # Calculate evaluation metrics for the forecast
        actual_values = city_data['eo cases'].values[-1:]  # Actual values for the last 1 year
        predicted_values = np.array([forecast_2024])  # Forecasted value for 2024
        
        mae = mean_absolute_error(actual_values, predicted_values)
        mse = mean_squared_error(actual_values, predicted_values)
        rmse = np.sqrt(mse)
        mape = np.mean(np.abs((actual_values - predicted_values) / actual_values)) * 100
        
        # Append the evaluation metrics to the respective lists
        mae_list.append(mae)
        mse_list.append(mse)
        rmse_list.append(rmse)
        mape_list.append(mape)
        
        # Print the evaluation metrics for the forecast
        print(f"Evaluation metrics for {city}:")
        print(f"MAE: {mae:.2f}")
        print(f"MSE: {mse:.2f}")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAPE: {mape:.2f}%")
        print(f"R2 Score: {r2:.2f}")
        print("-------------------------------------")
    else:
        print(f"Insufficient data for {city}. Skipping the forecast.")
        
# Calculate the average evaluation metrics across all cities
average_mae = np.mean(mae_list)
average_mse = np.mean(mse_list)
average_rmse = np.mean(rmse_list)
average_mape = np.mean(mape_list)

# Print the average evaluation metrics across all cities
print("Average Evaluation Metrics for All Cities:")
print(f"Average MAE: {average_mae:.2f}")
print(f"Average MSE: {average_mse:.2f}")
print(f"Average RMSE: {average_rmse:.2f}")
print(f"Average MAPE: {average_mape:.2f}%")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# Evaluation metrics for Ahmedabad:
# MAE: 56.57
# MSE: 3200.66
# RMSE: 56.57
# MAPE: 7.40%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Mumbai:
# MAE: 1701.81
# MSE: 2896147.11
# RMSE: 1701.81
# MAPE: 30.01%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Kolkata:
# MAE: 615.71
# MSE: 379099.99
# RMSE: 615.71
# MAPE: 29.64%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Kozhikode:
# MAE: 46.47
# MSE: 2159.91
# RMSE: 46.47
# MAPE: 14.94%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Surat:
# MAE: 341.00
# MSE: 116281.87
# RMSE: 341.00
# MAPE: 51.43%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Nagpur:
# MAE: 71.57
# MSE: 5122.31
# RMSE: 71.57
# MAPE: 13.23%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Pune:
# MAE: 140.60
# MSE: 19767.38
# RMSE: 140.60
# MAPE: 19.94%
# R2 Score: nan
# -------------------------------------
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Evaluation metrics for Lucknow:
# MAE: 1416.61
# MSE: 2006776.36
# RMSE: 1416.61
# MAPE: 41.18%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Kochi:
# MAE: 50.88
# MSE: 2588.73
# RMSE: 50.88
# MAPE: 11.72%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Patna:
# MAE: 299.04
# MSE: 89424.53
# RMSE: 299.04
# MAPE: 25.32%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Jaipur:
# MAE: 159.26
# MSE: 25362.35
# RMSE: 159.26
# MAPE: 3.73%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Coimbatore:
# MAE: 87.01
# MSE: 7570.23
# RMSE: 87.01
# MAPE: 47.81%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Indore:
# MAE: 14.01
# MSE: 196.23
# RMSE: 14.01
# MAPE: 3.55%
# R2 Score: nan
# -------------------------------------
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Evaluation metrics for Hyderabad:
# MAE: 1536.77
# MSE: 2361675.14
# RMSE: 1536.77
# MAPE: 31.62%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Bengaluru:
# MAE: 988.89
# MSE: 977906.16
# RMSE: 988.89
# MAPE: 36.42%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Ghaziabad:
# MAE: 197.23
# MSE: 38900.58
# RMSE: 197.23
# MAPE: 33.15%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Chennai:
# MAE: 100.35
# MSE: 10069.85
# RMSE: 100.35
# MAPE: 11.95%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Kanpur:
# MAE: 205.83
# MSE: 42365.15
# RMSE: 205.83
# MAPE: 47.54%
# R2 Score: nan
# -------------------------------------
# Evaluation metrics for Delhi:
# MAE: 286.03
# MSE: 81814.57
# RMSE: 286.03
# MAPE: 5.61%
# R2 Score: nan
# -------------------------------------
# Average Evaluation Metrics for All Cities:
# Average MAE: 437.67
# Average MSE: 477180.48
# Average RMSE: 437.67
# Average MAPE: 24.54%
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\3919688859.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)

# %%
import matplotlib.pyplot as plt

# Iterate over each city and make forecasts for 2024
for city in cities:
    # Filter the data for the current city
    city_data = data[data['City'] == city]
    
    # Check if the data is available for the current city
    if city_data.shape[0] >= 4:
        # Split the data into training and testing sets
        train_data = city_data[:-1]  # Use all but the last 3 years as training data
        
        # Extract the 'eo cases' values as a 1D array
        train_cases = train_data['eo cases'].values
        
        # Fit the ARIMA model on the training data
        model = ARIMA(train_cases, order=(1, 1, 0))  # ARIMA(1, 1, 0) model
        model_fit = model.fit()
        
        # Forecast 'eo cases' for the year 2024
        forecast_2024 = model_fit.forecast(steps=1)[0]  # Get only the forecast for 2024
        
        # Append the forecast for the current city to the main DataFrame
        city_forecast_2024_df = pd.DataFrame({
            'City': city,
            'Forecast': forecast_2024
        }, index=[0])  # Create a DataFrame with a single row
        
        # Append the city forecast for 2024 to the main DataFrame
        forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
        
        # Plot the variation of previous years' data and forecasted data for 2024
        plt.figure()
        plt.plot(city_data['Year'], city_data['eo cases'], marker='o', label='Previous Years')
        plt.plot(2024, forecast_2024, marker='o', color='red', label='2024 Forecast')
        plt.xlabel('Year')
        plt.ylabel('EO Cases')
        plt.title(f"EO Cases Variation for {city}")
        plt.legend()
        plt.show()
        
    else:
        print(f"Insufficient data for {city}. Skipping the forecast.")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
# C:\Users\USER\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\USER\AppData\Local\Temp\ipykernel_7788\1539503708.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   forecast_2024_df = forecast_2024_df.append(city_forecast_2024_df, ignore_index=True)
